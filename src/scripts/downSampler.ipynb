# %%
import os
import h5py
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset

# %%
TEMPERATURE = 'temperature'
VELX = 'velx'
VELY = 'vely'
PRESSURE = 'pressure'


class SimpleLoaderBubbleML(Dataset):
    def __init__(self, filename):
        self.filename = filename
        self.data = h5py.File(self.filename, 'r')
        self.timesteps = self.data[TEMPERATURE][:].shape[0]
    
    def __len__(self):
        return self.timesteps - 1

    def _get_state(self, idx):
        r"""
        The input is the temperature, x-velocity, and y-velocity at time == idx
        """
        temp = torch.from_numpy(self.data[TEMPERATURE][idx])
        velx = torch.from_numpy(self.data[VELX][idx])
        vely = torch.from_numpy(self.data[VELY][idx])
        # returns a stack with shape [3 x Y x X]
        return torch.stack((temp, velx, vely), dim=0)
    
    def __getitem__(self, idx):
        r"""
        As input, get temperature and velocities at time == idx.
        As the output label, get the temperature at time == idx + 1.
        """
        input = self._get_state(idx)
        label = self._get_state(idx+1)
        return input, label
    
    def get_full_stack(self):
        r"""
        Retrieve the full temporal domain stack for the entire simulation.
        The returned stack will have shape: [timesteps, channels, Y, X].
        """
        # Load temperature, velx, and vely data from the HDF5 file
        temp_data = torch.from_numpy(self.data[TEMPERATURE][:])  # Shape: [timesteps, Y, X]
        velx_data = torch.from_numpy(self.data[VELX][:])         # Shape: [timesteps, Y, X]
        vely_data = torch.from_numpy(self.data[VELY][:])         # Shape: [timesteps, Y, X]
        
        # Stack the data along the channel dimension
        full_stack = torch.stack((temp_data, velx_data, vely_data), dim=1)  # Shape: [timesteps, channels, Y, X]
        return full_stack

# %%
import os
import h5py
import torch
import torch.nn.functional as F

#redim = False

# Parameters
data_path = '../../data/prjs1359/PoolBoiling-SubCooled-FC72-2D-0.1'
#data_path = r'D:/datasets/pool-boiling-subcooled-fc72-2d-0.1/PoolBoiling-SubCooled-FC72-2D-0.1/'

downsample_factor = 8  # Downsample factor for spatial dimensions
#if redim:
#    output_path = os.path.join(data_path, 'downsampled_redimensionalized/')
#else:
#    output_path = os.path.join(data_path, 'downsampled_' + str(downsample_factor) + '/')
output_path = '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/downsampled_' + str(downsample_factor)

#data_path = data_path + 'redimensionalized/' if redim else data_path

os.makedirs(output_path, exist_ok=True)  # Ensure output directory exists

keys_to_downsample = [
    'temperature',
    'velx',
    'vely',
    'dfun',
    'pressure',
    'x',
    'y'
]

keys_to_copy = [
    'real-runtime-params',
    'int-runtime-params'
]


def downsample(data, factor):
    """
    Downsample a tensor's spatial dimensions by the given factor.
    Args:
        data (torch.Tensor): 3D or 4D tensor [timesteps, channels, Y, X].
        factor (int): Downsampling factor for spatial dimensions.
    Returns:
        torch.Tensor: Downsampled tensor.
    """
    if factor == 1:  # No downsampling needed
        return data
    _, _, height, width = data.shape
    new_height, new_width = height // factor, width // factor

    # Use PyTorch's interpolate for downsampling
    downsampled = F.interpolate(data, size=(new_height, new_width), mode='area')
    return downsampled


# Process each file in the directory
files = [f for f in os.listdir(data_path) if f.endswith('.hdf5')]
print(files)


for file in files:
    input_file = os.path.join(data_path, file)
    output_file = os.path.join(output_path, file)

    with h5py.File(input_file, 'r') as input_data:
        # Prepare output HDF5 file
        with h5py.File(output_file, 'w') as output_data:
            for key in input_data.keys():
                dataset = input_data[key][:]
                print(f"Processing key '{key}' in file '{file}' with shape {dataset.shape}")

                if key in keys_to_downsample:
                    # Downsample spatial-temporal data
                    if len(dataset.shape) >= 3:  # Process only 3D or 4D data
                        if len(dataset.shape) == 3:
                            dataset = torch.from_numpy(dataset).unsqueeze(1)  # Add channel dimension
                        else:
                            dataset = torch.from_numpy(dataset)

                        downsampled = downsample(dataset, downsample_factor)
                        downsampled = downsampled.numpy()
                        # Remove channel dimension for datasets that were originally 3D
                        if downsampled.shape[1] == 1:
                            downsampled = downsampled[:, 0]
                    else:
                        raise ValueError(f"Key '{key}' expected to have spatial dimensions but doesn't.")

                    # Save downsampled 
                    if key == 'temperature':
                        print('max termperature:', np.max(downsampled))
                    output_data.create_dataset(key, data=downsampled)

                elif key in keys_to_copy:
                    # Directly copy keys
                    output_data.create_dataset(key, data=dataset)

                else:
                    print(f"Skipping key '{key}' as it's not in keys_to_downsample or keys_to_copy.")

            print(f"File '{file}' processed and saved to '{output_file}'.")

print("Downsampling completed for all files.")
# Out:
# ['Twall-79.hdf5', 'Twall-97.hdf5', 'Twall-108.hdf5', 'Twall-100.hdf5', 'Twall-110.hdf5', 'Twall-81.hdf5', 'Twall-90.hdf5', 'Twall-88.hdf5', 'Twall-106.hdf5', 'Twall-95.hdf5', 'Twall-102.hdf5', 'Twall-98.hdf5', 'Twall-92.hdf5', 'Twall-85.hdf5', 'Twall-103.hdf5']
# Processing key 'dfun' in file 'Twall-79.hdf5' with shape (2001, 384, 384)
# Processing key 'pressure' in file 'Twall-79.hdf5' with shape (2001, 384, 384)
# Processing key 'temperature' in file 'Twall-79.hdf5' with shape (2001, 384, 384)
# max termperature: 0.9132295615863075
# Processing key 'velx' in file 'Twall-79.hdf5' with shape (2001, 384, 384)
# Processing key 'vely' in file 'Twall-79.hdf5' with shape (2001, 384, 384)
# Processing key 'x' in file 'Twall-79.hdf5' with shape (2001, 384, 384)
# Processing key 'y' in file 'Twall-79.hdf5' with shape (2001, 384, 384)
# File 'Twall-79.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/downsampled_8/Twall-79.hdf5'.
# Processing key 'dfun' in file 'Twall-97.hdf5' with shape (2001, 384, 384)
# Processing key 'pressure' in file 'Twall-97.hdf5' with shape (2001, 384, 384)
# Processing key 'temperature' in file 'Twall-97.hdf5' with shape (2001, 384, 384)
# max termperature: 0.9161034909277364
# Processing key 'velx' in file 'Twall-97.hdf5' with shape (2001, 384, 384)
# Processing key 'vely' in file 'Twall-97.hdf5' with shape (2001, 384, 384)
# Processing key 'x' in file 'Twall-97.hdf5' with shape (2001, 384, 384)
# Processing key 'y' in file 'Twall-97.hdf5' with shape (2001, 384, 384)
# File 'Twall-97.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/downsampled_8/Twall-97.hdf5'.
# Processing key 'dfun' in file 'Twall-108.hdf5' with shape (2001, 384, 384)
# Processing key 'pressure' in file 'Twall-108.hdf5' with shape (2001, 384, 384)
# Processing key 'temperature' in file 'Twall-108.hdf5' with shape (2001, 384, 384)
# max termperature: 0.9289341588527297
# Processing key 'velx' in file 'Twall-108.hdf5' with shape (2001, 384, 384)
# Processing key 'vely' in file 'Twall-108.hdf5' with shape (2001, 384, 384)
# Processing key 'x' in file 'Twall-108.hdf5' with shape (2001, 384, 384)
# Processing key 'y' in file 'Twall-108.hdf5' with shape (2001, 384, 384)
# File 'Twall-108.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/downsampled_8/Twall-108.hdf5'.
# Processing key 'dfun' in file 'Twall-100.hdf5' with shape (2001, 384, 384)
# Processing key 'pressure' in file 'Twall-100.hdf5' with shape (2001, 384, 384)
# Processing key 'temperature' in file 'Twall-100.hdf5' with shape (2001, 384, 384)
# max termperature: 0.9202448616130486
# Processing key 'velx' in file 'Twall-100.hdf5' with shape (2001, 384, 384)
# Processing key 'vely' in file 'Twall-100.hdf5' with shape (2001, 384, 384)
# Processing key 'x' in file 'Twall-100.hdf5' with shape (2001, 384, 384)
# Processing key 'y' in file 'Twall-100.hdf5' with shape (2001, 384, 384)
# File 'Twall-100.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/downsampled_8/Twall-100.hdf5'.
# Processing key 'dfun' in file 'Twall-110.hdf5' with shape (2001, 384, 384)
# Processing key 'pressure' in file 'Twall-110.hdf5' with shape (2001, 384, 384)
# Processing key 'temperature' in file 'Twall-110.hdf5' with shape (2001, 384, 384)
# max termperature: 0.9126824753412524
# Processing key 'velx' in file 'Twall-110.hdf5' with shape (2001, 384, 384)
# Processing key 'vely' in file 'Twall-110.hdf5' with shape (2001, 384, 384)
# Processing key 'x' in file 'Twall-110.hdf5' with shape (2001, 384, 384)
# Processing key 'y' in file 'Twall-110.hdf5' with shape (2001, 384, 384)
# File 'Twall-110.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/downsampled_8/Twall-110.hdf5'.
# Processing key 'dfun' in file 'Twall-81.hdf5' with shape (2001, 384, 384)
# Processing key 'pressure' in file 'Twall-81.hdf5' with shape (2001, 384, 384)
# Processing key 'temperature' in file 'Twall-81.hdf5' with shape (2001, 384, 384)
# max termperature: 0.9129693480339311
# Processing key 'velx' in file 'Twall-81.hdf5' with shape (2001, 384, 384)
# Processing key 'vely' in file 'Twall-81.hdf5' with shape (2001, 384, 384)
# Processing key 'x' in file 'Twall-81.hdf5' with shape (2001, 384, 384)
# Processing key 'y' in file 'Twall-81.hdf5' with shape (2001, 384, 384)
# File 'Twall-81.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/downsampled_8/Twall-81.hdf5'.
# Processing key 'dfun' in file 'Twall-90.hdf5' with shape (2001, 384, 384)
# Processing key 'pressure' in file 'Twall-90.hdf5' with shape (2001, 384, 384)
# Processing key 'temperature' in file 'Twall-90.hdf5' with shape (2001, 384, 384)
# max termperature: 0.9242054271486293
# Processing key 'velx' in file 'Twall-90.hdf5' with shape (2001, 384, 384)
# Processing key 'vely' in file 'Twall-90.hdf5' with shape (2001, 384, 384)
# Processing key 'x' in file 'Twall-90.hdf5' with shape (2001, 384, 384)
# Processing key 'y' in file 'Twall-90.hdf5' with shape (2001, 384, 384)
# File 'Twall-90.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/downsampled_8/Twall-90.hdf5'.
# Processing key 'dfun' in file 'Twall-88.hdf5' with shape (2001, 384, 384)
# Processing key 'pressure' in file 'Twall-88.hdf5' with shape (2001, 384, 384)
# Processing key 'temperature' in file 'Twall-88.hdf5' with shape (2001, 384, 384)
# max termperature: 0.9040340200286885
# Processing key 'velx' in file 'Twall-88.hdf5' with shape (2001, 384, 384)
# Processing key 'vely' in file 'Twall-88.hdf5' with shape (2001, 384, 384)
# Processing key 'x' in file 'Twall-88.hdf5' with shape (2001, 384, 384)
# Processing key 'y' in file 'Twall-88.hdf5' with shape (2001, 384, 384)
# File 'Twall-88.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/downsampled_8/Twall-88.hdf5'.
# Processing key 'dfun' in file 'Twall-106.hdf5' with shape (2001, 384, 384)
# Processing key 'pressure' in file 'Twall-106.hdf5' with shape (2001, 384, 384)
# Processing key 'temperature' in file 'Twall-106.hdf5' with shape (2001, 384, 384)
# max termperature: 0.9223196810671864
# Processing key 'velx' in file 'Twall-106.hdf5' with shape (2001, 384, 384)
# Processing key 'vely' in file 'Twall-106.hdf5' with shape (2001, 384, 384)
# Processing key 'x' in file 'Twall-106.hdf5' with shape (2001, 384, 384)
# Processing key 'y' in file 'Twall-106.hdf5' with shape (2001, 384, 384)
# File 'Twall-106.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/downsampled_8/Twall-106.hdf5'.
# Processing key 'dfun' in file 'Twall-95.hdf5' with shape (2001, 384, 384)
# Processing key 'pressure' in file 'Twall-95.hdf5' with shape (2001, 384, 384)
# Processing key 'temperature' in file 'Twall-95.hdf5' with shape (2001, 384, 384)
# max termperature: 0.9117849808381583
# Processing key 'velx' in file 'Twall-95.hdf5' with shape (2001, 384, 384)
# Processing key 'vely' in file 'Twall-95.hdf5' with shape (2001, 384, 384)
# Processing key 'x' in file 'Twall-95.hdf5' with shape (2001, 384, 384)
# Processing key 'y' in file 'Twall-95.hdf5' with shape (2001, 384, 384)
# File 'Twall-95.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/downsampled_8/Twall-95.hdf5'.
# Processing key 'dfun' in file 'Twall-102.hdf5' with shape (2001, 384, 384)
# Processing key 'pressure' in file 'Twall-102.hdf5' with shape (2001, 384, 384)
# Processing key 'temperature' in file 'Twall-102.hdf5' with shape (2001, 384, 384)
# max termperature: 0.910818595498879
# Processing key 'velx' in file 'Twall-102.hdf5' with shape (2001, 384, 384)
# Processing key 'vely' in file 'Twall-102.hdf5' with shape (2001, 384, 384)
# Processing key 'x' in file 'Twall-102.hdf5' with shape (2001, 384, 384)
# Processing key 'y' in file 'Twall-102.hdf5' with shape (2001, 384, 384)
# File 'Twall-102.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/downsampled_8/Twall-102.hdf5'.
# Processing key 'dfun' in file 'Twall-98.hdf5' with shape (2001, 384, 384)
# Processing key 'pressure' in file 'Twall-98.hdf5' with shape (2001, 384, 384)
# Processing key 'temperature' in file 'Twall-98.hdf5' with shape (2001, 384, 384)
# max termperature: 0.9143935030024624
# Processing key 'velx' in file 'Twall-98.hdf5' with shape (2001, 384, 384)
# Processing key 'vely' in file 'Twall-98.hdf5' with shape (2001, 384, 384)
# Processing key 'x' in file 'Twall-98.hdf5' with shape (2001, 384, 384)
# Processing key 'y' in file 'Twall-98.hdf5' with shape (2001, 384, 384)
# File 'Twall-98.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/downsampled_8/Twall-98.hdf5'.
# Processing key 'dfun' in file 'Twall-92.hdf5' with shape (2001, 384, 384)
# Processing key 'pressure' in file 'Twall-92.hdf5' with shape (2001, 384, 384)
# Processing key 'temperature' in file 'Twall-92.hdf5' with shape (2001, 384, 384)
# max termperature: 0.9169800312321053
# Processing key 'velx' in file 'Twall-92.hdf5' with shape (2001, 384, 384)
# Processing key 'vely' in file 'Twall-92.hdf5' with shape (2001, 384, 384)
# Processing key 'x' in file 'Twall-92.hdf5' with shape (2001, 384, 384)
# Processing key 'y' in file 'Twall-92.hdf5' with shape (2001, 384, 384)
# File 'Twall-92.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/downsampled_8/Twall-92.hdf5'.
# Processing key 'dfun' in file 'Twall-85.hdf5' with shape (2001, 384, 384)
# Processing key 'pressure' in file 'Twall-85.hdf5' with shape (2001, 384, 384)
# Processing key 'temperature' in file 'Twall-85.hdf5' with shape (2001, 384, 384)
# max termperature: 0.9153872263041413
# Processing key 'velx' in file 'Twall-85.hdf5' with shape (2001, 384, 384)
# Processing key 'vely' in file 'Twall-85.hdf5' with shape (2001, 384, 384)
# Processing key 'x' in file 'Twall-85.hdf5' with shape (2001, 384, 384)
# Processing key 'y' in file 'Twall-85.hdf5' with shape (2001, 384, 384)
# File 'Twall-85.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/downsampled_8/Twall-85.hdf5'.
# Processing key 'dfun' in file 'Twall-103.hdf5' with shape (2001, 384, 384)
# Processing key 'pressure' in file 'Twall-103.hdf5' with shape (2001, 384, 384)
# Processing key 'temperature' in file 'Twall-103.hdf5' with shape (2001, 384, 384)
# max termperature: 0.9263525071969572
# Processing key 'velx' in file 'Twall-103.hdf5' with shape (2001, 384, 384)
# Processing key 'vely' in file 'Twall-103.hdf5' with shape (2001, 384, 384)
# Processing key 'x' in file 'Twall-103.hdf5' with shape (2001, 384, 384)
# Processing key 'y' in file 'Twall-103.hdf5' with shape (2001, 384, 384)
# File 'Twall-103.hdf5' processed and saved to '../../data/PoolBoiling-SubCooled-FC72-2D-0.1/downsampled_8/Twall-103.hdf5'.
# Downsampling completed for all files.
